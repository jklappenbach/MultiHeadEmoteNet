# %%
from pathlib import Path
from component.dataset.dataset import verify_h5_images  # adjust import if needed

h5_dir = Path("data/h5_datasets")

for h5_file in sorted(h5_dir.glob("*.h5")):
    print(f"Verifying: {h5_file}")
    verify_h5_images(h5_file)
# Out:
# Verifying: data/h5_datasets/8-facial-expressions-for-yolo.h5
# Verification summary for: data/h5_datasets/8-facial-expressions-for-yolo.h5
# Checked images: 0
# Failures: 0
# Unique labels (0): []
# Verifying: data/h5_datasets/emotion-detection-fer.h5
# Verification summary for: data/h5_datasets/emotion-detection-fer.h5
# Checked images: 71774
# Failures: 0
# Unique labels (7): [0, 2, 3, 4, 5, 6, 8]
# Per-label examples (up to 5 each):
#   label 0: indices [3171, 3172, 3173, 3174, 3175]
#   label 2: indices [14381, 14382, 14383, 14384, 14385]
#   label 3: indices [19782, 19783, 19784, 19785, 19786]
#   label 4: indices [7166, 7167, 7168, 7169, 7170]
#   label 5: indices [14817, 14818, 14819, 14820, 14821]
#   label 6: indices [23879, 23880, 23881, 23882, 23883]
#   label 8: indices [0, 1, 2, 3, 4]
# Verifying: data/h5_datasets/emotion-recognition-dataset.h5
# ---------------------------------------------------------------------------
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 16.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.7 MB/s eta 0:00:00
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from component.dataset.dataset import h5_to_dataset
import matplotlib.pyplot as plt

dataset = h5_to_dataset(h5_file)
image, label = dataset[0]

# %%
plt.imshow(image)
plt.title(f"Label: {label}")
plt.axis("off")
plt.show()
