# %%
from pathlib import Path
from component.dataset.dataset import verify_h5_images  # adjust import if needed

h5_dir = Path("data/h5_datasets")

for h5_file in sorted(h5_dir.glob("*.h5")):
    print(f"Verifying: {h5_file}")
    verify_h5_images(h5_file)
# Out:
# Verifying: data/h5_datasets/8-facial-expressions-for-yolo.h5
# Traceback (most recent call last):
#   File "/snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_comm.py", line 736, in make_thread_stack_str
#     append('file="%s" line="%s">' % (make_valid_xml_value(my_file), lineno))
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_xml.py", line 36, in make_valid_xml_value
#     return s.replace("&", "&amp;").replace('<', '&lt;').replace('>', '&gt;').replace('"', '&quot;')
#            ^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'replace'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       6 for h5_file in sorted(h5_dir.glob("*.h5")):
#       7     print(f"Verifying: {h5_file}")
# ----> 8     verify_h5_images(h5_file)
#
# File ~/code/ml/MultiHeadEmoteNet/component/dataset/dataset.py:220, in verify_h5_images(h5_path, limit, stop_on_error, examples_per_label, show_examples, save_dir)
#     195 def verify_h5_images(
#     196     h5_path: str | Path,
#     197     limit: Optional[int] = None,
#    (...)    201     save_dir: Optional[str | Path] = None,
#     202 ) -> Dict[str, Any]:
#     203     """Verify that each element in 'images' can be decoded as an image.
#     204
#     205     Attempts to open each image with Pillow. Any failures are captured and
#    (...)    218         save_dir: if provided, also save per-label example grids as PNGs to this folder
#     219     """
# --> 220     h5_path = str(h5_path)
#     221     failures: List[Dict[str, Any]] = []
#     222     total = 0
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_frame.py:888, in PyDBFrame.trace_dispatch(self, frame, event, arg)
#     885             stop = False
#     887 if plugin_stop:
# --> 888     stopped_on_plugin = plugin_manager.stop(main_debugger, frame, event, self._args, stop_info, arg, step_cmd)
#     889 elif stop:
#     890     if is_line:
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/jupyter_debug/pydev_jupyter_plugin.py:185, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     183     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     184     if frame:
# --> 185         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     186         return True
#     187 return False
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/pydevd.py:1196, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1193         from_this_thread.append(frame_id)
#    1195 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1196     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /snap/pycharm-professional/548/plugins/python-ce/helpers/pydev/pydevd.py:1211, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1208             self._call_mpl_hook()
#    1210         self.process_internal_commands()
# -> 1211         time.sleep(0.01)
#    1213 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1215 # process any stepping instructions
#
# KeyboardInterrupt:
